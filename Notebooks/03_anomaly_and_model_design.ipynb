# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Build Autoencoder

# %%
# 1. LOAD DATA (Assuming you have the CSV in your environment)
# !wget https://archive.ics.uci.edu/static/public/601/ai4i+2020+predictive+maintenance+dataset.zip
# !unzip -o ai4i+2020+predictive+maintenance+dataset.zip
df = pd.read_csv('/content/ai4i_engineered_features.csv')

# 2. FEATURE ENGINEERING (Required for the Autoencoder to have rich data)
df['temp_diff'] = df['Process temperature [K]'] - df['Air temperature [K]']
df['stress_index'] = df['Torque [Nm]'] / (df['Rotational speed [rpm]'] + 1e-5)
df['torque_wear'] = df['Torque [Nm]'] * df['Tool wear [min]']

# Select Features & Target
features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]',
            'Torque [Nm]', 'Tool wear [min]', 'temp_diff', 'stress_index', 'torque_wear']
target = 'Machine failure'

X = df[features]
y = df[target]

# 3. CHRONOLOGICAL SPLIT (Maintaining time-series integrity)
train_size = int(len(X) * 0.8)
X_train_raw, X_test_raw = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# 4. SCALING (Fit only on Train to avoid data leakage)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_raw)
X_test = scaler.transform(X_test_raw)

# 5. FILTER FOR NORMAL DATA (Autoencoders learn 'Normal' behavior)
# We only train on rows where Machine failure == 0
X_train_normal = X_train[y_train == 0]

# 6. BUILD THE AUTOENCODER
input_dim = X_train.shape[1]

autoencoder = models.Sequential([
    # Encoder
    layers.Dense(16, activation='relu', input_shape=(input_dim,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(4, activation='relu'), # Bottleneck

    # Decoder
    layers.Dense(8, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(input_dim, activation='linear') # Output matches input size
])

autoencoder.compile(optimizer='adam', loss='mse')

# 7. TRAIN
# Note: Input and Output are BOTH X_train_normal (Self-supervised)
history = autoencoder.fit(
    X_train_normal, X_train_normal,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.7335 - val_loss: 1.0486
# Epoch 2/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4115 - val_loss: 0.8902
# Epoch 3/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3301 - val_loss: 0.8380
# Epoch 4/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2957 - val_loss: 0.8185
# Epoch 5/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2727 - val_loss: 0.7917
# Epoch 6/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2565 - val_loss: 0.7461
# Epoch 7/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2399 - val_loss: 0.7236
# Epoch 8/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2262 - val_loss: 0.6994
# Epoch 9/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2163 - val_loss: 0.6647
# Epoch 10/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2069 - val_loss: 0.6447
# Epoch 11/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2002 - val_loss: 0.6585
# Epoch 12/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1932 - val_loss: 0.6665
# Epoch 13/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1870 - val_loss: 0.6146
# Epoch 14/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1806 - val_loss: 0.6428
# Epoch 15/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1762 - val_loss: 0.6383
# Epoch 16/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1708 - val_loss: 0.6414
# Epoch 17/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1674 - val_loss: 0.6433
# Epoch 18/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1627 - val_loss: 0.6251
# Epoch 19/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1585 - val_loss: 0.5951
# Epoch 20/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1543 - val_loss: 0.6258
# Epoch 21/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1492 - val_loss: 0.6134
# Epoch 22/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1438 - val_loss: 0.5602
# Epoch 23/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1366 - val_loss: 0.5016
# Epoch 24/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1292 - val_loss: 0.4538
# Epoch 25/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1241 - val_loss: 0.4320
# Epoch 26/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1225 - val_loss: 0.4471
# Epoch 27/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1198 - val_loss: 0.4130
# Epoch 28/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1153 - val_loss: 0.4046
# Epoch 29/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1147 - val_loss: 0.4141
# Epoch 30/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1114 - val_loss: 0.3932
# Epoch 31/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1126 - val_loss: 0.4015
# Epoch 32/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1099 - val_loss: 0.3722
# Epoch 33/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1078 - val_loss: 0.4662
# Epoch 34/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1061 - val_loss: 0.3867
# Epoch 35/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1034 - val_loss: 0.4204
# Epoch 36/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1027 - val_loss: 0.3872
# Epoch 37/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0988 - val_loss: 0.3450
# Epoch 38/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1009 - val_loss: 0.3313
# Epoch 39/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0952 - val_loss: 0.3208
# Epoch 40/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0915 - val_loss: 0.2940
# Epoch 41/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0908 - val_loss: 0.3063
# Epoch 42/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0862 - val_loss: 0.2695
# Epoch 43/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0850 - val_loss: 0.2914
# Epoch 44/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0817 - val_loss: 0.2681
# Epoch 45/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0852 - val_loss: 0.2559
# Epoch 46/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0796 - val_loss: 0.2603
# Epoch 47/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0767 - val_loss: 0.2665
# Epoch 48/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0765 - val_loss: 0.2424
# Epoch 49/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0751 - val_loss: 0.2261
# Epoch 50/50
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0735 - val_loss: 0.2177

# %% [markdown]
# # Train ONLY on Normal Data

# %%
# --- 1. Filter for Normal Samples ---
# We use the y_train we created in the previous step to mask the features
# Only '0' (no failure) samples are used to teach the model 'Normal' behavior
X_train_normal = X_train[y_train == 0]

print(f"Original Training Shape: {X_train.shape}")
print(f"Filtered (Normal Only) Training Shape: {X_train_normal.shape}")

# --- 2. Define the Autoencoder Architecture ---
input_dim = X_train_normal.shape[1]

autoencoder = models.Sequential([
    # Encoder: Compress features into a bottleneck
    layers.Dense(16, activation='relu', input_shape=(input_dim,)),
    layers.Dense(8, activation='relu'),
    layers.Dense(4, activation='relu', name="bottleneck"), # Latent Space

    # Decoder: Reconstruct features back to original dimension
    layers.Dense(8, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(input_dim, activation='linear')
])

autoencoder.compile(optimizer='adam', loss='mse')

# --- 3. Train the Model ---
# Notice: we pass X_train_normal as both the features (X) and the targets (y)
history = autoencoder.fit(
    X_train_normal,
    X_train_normal,
    epochs=50,
    batch_size=32,
    validation_split=0.15, # Using 15% of the normal data for validation
    shuffle=True,          # Shuffle normal data so the model doesn't learn sequence order
    verbose=1
)

# --- 4. Plot Training History ---
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Autoencoder Reconstruction Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.show()
# Out:
# Original Training Shape: (8000, 8)
# Filtered (Normal Only) Training Shape: (7700, 8)
# Epoch 1/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.7401 - val_loss: 1.0703
# Epoch 2/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3769 - val_loss: 0.8947
# Epoch 3/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3169 - val_loss: 0.8420
# Epoch 4/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2920 - val_loss: 0.7834
# Epoch 5/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2679 - val_loss: 0.7662
# Epoch 6/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2460 - val_loss: 0.7430
# Epoch 7/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2323 - val_loss: 0.7388
# Epoch 8/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2234 - val_loss: 0.7507
# Epoch 9/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2168 - val_loss: 0.7235
# Epoch 10/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2117 - val_loss: 0.7247
# Epoch 11/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2065 - val_loss: 0.7093
# Epoch 12/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1983 - val_loss: 0.6644
# Epoch 13/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1791 - val_loss: 0.5734
# Epoch 14/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1501 - val_loss: 0.4794
# Epoch 15/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1251 - val_loss: 0.4344
# Epoch 16/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1056 - val_loss: 0.3648
# Epoch 17/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0961 - val_loss: 0.3535
# Epoch 18/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0904 - val_loss: 0.3475
# Epoch 19/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0863 - val_loss: 0.3253
# Epoch 20/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0828 - val_loss: 0.3317
# Epoch 21/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0793 - val_loss: 0.3216
# Epoch 22/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0771 - val_loss: 0.3079
# Epoch 23/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0731 - val_loss: 0.3017
# Epoch 24/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0723 - val_loss: 0.2908
# Epoch 25/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0691 - val_loss: 0.2775
# Epoch 26/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0667 - val_loss: 0.2735
# Epoch 27/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0647 - val_loss: 0.2692
# Epoch 28/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0641 - val_loss: 0.2691
# Epoch 29/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0608 - val_loss: 0.2674
# Epoch 30/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0604 - val_loss: 0.2557
# Epoch 31/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0585 - val_loss: 0.2488
# Epoch 32/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0564 - val_loss: 0.2424
# Epoch 33/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0556 - val_loss: 0.2400
# Epoch 34/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0538 - val_loss: 0.2435
# Epoch 35/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0539 - val_loss: 0.2397
# Epoch 36/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0517 - val_loss: 0.2485
# Epoch 37/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0509 - val_loss: 0.2337
# Epoch 38/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0496 - val_loss: 0.2311
# Epoch 39/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0502 - val_loss: 0.2461
# Epoch 40/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0496 - val_loss: 0.2304
# Epoch 41/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0479 - val_loss: 0.2197
# Epoch 42/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0473 - val_loss: 0.2227
# Epoch 43/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0468 - val_loss: 0.2243
# Epoch 44/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0450 - val_loss: 0.2181
# Epoch 45/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0452 - val_loss: 0.2228
# Epoch 46/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0446 - val_loss: 0.2159
# Epoch 47/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0434 - val_loss: 0.2234
# Epoch 48/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0433 - val_loss: 0.2271
# Epoch 49/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - val_loss: 0.2185
# Epoch 50/50
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0423 - val_loss: 0.2084

# %% [markdown]
# ## Anomaly Detection Threshold
#
# The autoencoder was trained on normal operating data to learn its underlying patterns. Reconstruction error was used as an anomaly score.
#
# A threshold was defined using the 95th percentile of reconstruction error on training data. Any instance with error above this threshold was classified as anomalous.
#
# This approach allows the model to identify deviations from normal behavior without requiring labeled failure data.

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# 1. Calculate Reconstruction Error (MSE) for Test Set
# autoencoder.predict returns the reconstructed version of X_test
X_test_pred = autoencoder.predict(X_test)
mse_test = np.mean(np.power(X_test - X_test_pred, 2), axis=1)

# 2. Set Threshold using Training Error
# We calculate error on X_train_normal to see what "good" reconstruction looks like
X_train_pred = autoencoder.predict(X_train_normal)
mse_train = np.mean(np.power(X_train_normal - X_train_pred, 2), axis=1)

threshold = np.mean(mse_train) + 2 * np.std(mse_train)
print(f"Calculated Anomaly Threshold: {threshold:.4f}")

# 3. Classify Anomalies
# If MSE > Threshold, it's an anomaly (1), otherwise normal (0)
y_pred = [1 if e > threshold else 0 for e in mse_test]

# 4. Evaluation and Visualization
print("\n--- Classification Report ---")
print(classification_report(y_test, y_pred))

# Plotting the Reconstruction Error vs Threshold
plt.figure(figsize=(12, 6))
plt.plot(mse_test, label='Reconstruction Error')
plt.axhline(y=threshold, color='r', linestyle='--', label='Threshold')
plt.title('Reconstruction Error on Test Set')
plt.xlabel('Sample Index')
plt.ylabel('MSE')
plt.legend()
plt.show()

# 5. Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Failure'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix: Autoencoder Anomaly Detection')
plt.show()
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Calculated Anomaly Threshold: 3.7686
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1961
#            1       0.00      0.00      0.00        39
#
#     accuracy                           0.98      2000
#    macro avg       0.49      0.50      0.49      2000
# weighted avg       0.96      0.98      0.97      2000

# %%
def build_lstm_with_attention(input_shape):
    # 1. Input Layer (Sequence Length, Number of Features)
    inputs = layers.Input(shape=input_shape)

    # 2. LSTM Layer
    # return_sequences=True is REQUIRED to pass data to an Attention layer
    lstm_out = layers.LSTM(64, return_sequences=True)(inputs)
    lstm_out = layers.Dropout(0.2)(lstm_out)

    # 3. Simple Attention Mechanism
    # We calculate a weight for each time step
    attention = layers.Dense(1, activation='tanh')(lstm_out)
    attention = layers.Flatten()(attention)
    attention = layers.Activation('softmax')(attention)
    attention = layers.RepeatVector(64)(attention)
    attention = layers.Permute([2, 1])(attention)

    # Multiply the LSTM output by the attention weights
    sent_representation = layers.Multiply()([lstm_out, attention])
    sent_representation = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(sent_representation)

    # 4. Fully Connected Layers
    x = layers.Dense(32, activation='relu')(sent_representation)
    x = layers.Dropout(0.2)(x)

    # 5. Output Layer (Binary Classification)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    # Compile
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    )

    return model

# --- Usage ---
# Assuming X_train_seq shape is (9990, 10, num_features)
sequence_length = 10
num_features = X_train.shape[1] # Using the number of features from your scaling step

model = build_lstm_with_attention((sequence_length, num_features))
model.summary()

# --- Training ---
# history = model.fit(
#     X_train_seq, y_train_seq,
#     epochs=30,
#     batch_size=64,
#     validation_split=0.2,
#     class_weight={0: 1, 1: 10} # Handling the class imbalance (Failure is rare)
# )
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 10, 8)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ (None, 10, 64)    │     18,688 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 10, 64)    │          0 │ lstm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 10, 1)     │         65 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 10)        │          0 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 10)        │          0 │ flatten[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector       │ (None, 64, 10)    │          0 │ activation[0][0]  │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 10, 64)    │          0 │ repeat_vector[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 10, 64)    │          0 │ dropout[0][0],    │
# │                     │                   │            │ permute[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 64)        │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 32)        │      2,080 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32)        │          0 │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1)         │         33 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,866 (81.51 KB)
#  Trainable params: 20,866 (81.51 KB)
#  Non-trainable params: 0 (0.00 B)
